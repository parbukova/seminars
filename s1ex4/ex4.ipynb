# %%
f = open('input.txt')
numbers = f.readline()
sign = f.readline()
f.close()
plus = '+'
minus = '-'
comp = '*'
A = list(map(int, numbers.split()))
if sign == plus:
   res = A[0]+A[1]
elif sign == minus:
   res = A[0]-A[1]
else:
   res = A[0]*A[1]
print(res)
g = open('output.txt', 'w')
g.write(str(res))
g.close()
# Out:
# 3828
