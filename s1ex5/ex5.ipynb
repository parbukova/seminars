# %%
N = int(input("Введите число"))
b = int(input("Введите основание исходной системы счисления"))
c = int(input("Введите основание конечной системы счисления"))
# перевод в десятичную
if b != 10:
   power = 0
   dec = 0
   n = N
   while n > 0:
      rem1 = n%10
      dec += rem1*(b**power)
      n = n//10
      power += 1
# перевод из десятичной в с
   list = []
   while dec > 0:
      rem2 = dec % c
      list.append(rem2)
      dec = dec//c
   listt = map(str, list[::-1])
   listtt = ''.join(listt)
   print(listtt)
else:
   list1 = []
   N1 = N
   while N1 > 0:
      rem2 = N1 % c
      list1.append(rem2)
      N1 = N1//c
   list2 = map(str, list1[::-1])
   result = ''.join(list2)
   print(result)
# Out:
# 715
