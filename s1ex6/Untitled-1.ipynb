# %%
first = "7"
second = "235"
base = 8
one = first
two = second

length = max(len(first), len(second))
fin = ''
carry = 0
if length > len(first):
   zero = '0'
   p = length - len(first)
   one = str(zero*p + first)
if length > len(second):
   zero = '0'
   q = length - len(second)
   two = zero*q + second
for j in range(length - 1, -1, -1):
   one_str = one[j]
   one_int = int(one[j])
   for i in range(length - 1, -1, -1):
      one_str = one[j]
      one_int = int(one[j])
      two_str = two[i]
      two_int = int(two[i]) + carry
      carry = 0
      res = one_int*two_int
      if res > base:
         carry = res//base
         res = res%base

   res4 = res 
   fin = str(res4) + fin
print(fin)
# Out:
# 000
